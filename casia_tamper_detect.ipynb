# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(2)
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# %%
from PIL import Image, ImageChops, ImageEnhance
import os
import itertools
import random

# %%
def convert_to_ela_image(path, quality):
    temp_filename = 'temp_file_name.jpg'
    ela_filename = 'temp_ela.png'
    
    image = Image.open(path).convert('RGB')
    image.save(temp_filename, 'JPEG', quality = quality)
    temp_image = Image.open(temp_filename)
    
    ela_image = ImageChops.difference(image, temp_image)
    
    extrema = ela_image.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    if max_diff == 0:
        max_diff = 1
    scale = 255.0 / max_diff
    
    ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)
    
    return ela_image

# %%
# real_image_path = 'Au_cha_00027.jpg'
# Image.open(real_image_path)

# %%
# au = convert_to_ela_image(real_image_path, 95)
# au.save('au.png')

# %%
# fake_image_path = 'Tp_D_NNN_M_N_pla10121_cha00027_11669.jpg'
# Image.open(fake_image_path)

# %%
# Tp = convert_to_ela_image(fake_image_path, 95)
# Tp.save('tp.png')

# %%
image_size = (224, 224)
def prepare_image(image_path):
    return np.array(convert_to_ela_image(image_path, 90).resize(image_size)).flatten() / 255.0

# %%
X = [] # ELA converted images
Y = [] # 0 for fake, 1 for real

# %%
def prepare_data(path, cls):
    for dirname, _, filenames in os.walk(path):
        for filename in filenames:
            if filename.endswith('jpg') or filename.endswith('png'):
                try:
                    full_path = os.path.join(dirname, filename)
                    X.append(prepare_image(full_path))
                    Y.append(cls)
                except:
                    pass
                if len(Y) % 500 == 0:
                    print('Processing {} images'.format(len(Y)))

# %%
au_path = 'D:\Google Drive\CASIA2\Au'
prepare_data(au_path, 1)
random.shuffle(X)
X = X[:2100]
Y = Y[:2100]
print(len(X), len(Y))
# Out:
# Processing 500 images
# Processing 1000 images
# Processing 1500 images
# Processing 2000 images
# Processing 2500 images
# Processing 3000 images
# Processing 3500 images
# Processing 4000 images
# 2100 2100

# %%
tp_path = 'D:\Google Drive\CASIA2\Tp'
prepare_data(tp_path, 0)
print(len(X), len(Y))
# Out:
# Processing 2500 images
# Processing 3000 images
# Processing 3500 images
# 3568 3568

# %%
X = np.array(X)
Y = to_categorical(Y, 2)
X = X.reshape(-1, 224, 224, 3)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size = 0.2, random_state=5)

# %%
X = X.reshape(-1,1,1,1)
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
# Out:
# 2854 2854
# 714 714

# %%
X.shape
# Out:
# (537083904, 1, 1, 1)

# %%
def build_model():
    model = Sequential()
    model.add(Conv2D(32, 5, padding='valid', activation='relu', input_shape=[224, 224, 3]))
    model.add(Conv2D(32, 5, padding='valid', activation='relu', input_shape=[224, 224, 3]))
    model.add(MaxPool2D(pool_size=2))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))
    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 32)      2432
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 216, 216, 32)      25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 108, 108, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 108, 108, 32)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 373248)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               95551744
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 95,580,322
# Trainable params: 95,580,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 30
batch_size = 32
init_lr = 1e-4
optimizer = Adam(lr = init_lr, decay = init_lr/epochs)

# %%
model.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_acc', min_delta=0,patience=2, verbose=0, mode='auto')

checkpoint_filepath = 'ela/checkpoint'
model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=True, monitor='val_accuracy', mode='max', save_best_only=True)

# %%
history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, Y_val), callbacks=[early_stopping, model_checkpoint_callback])
# Out:
# Epoch 1/30
# 90/90 [==============================] - ETA: 0s - loss: 0.4306 - accuracy: 0.8013WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 90/90 [==============================] - 22s 250ms/step - loss: 0.4306 - accuracy: 0.8013 - val_loss: 0.2972 - val_accuracy: 0.8992
# Epoch 2/30
# 90/90 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.9082WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 90/90 [==============================] - 21s
ARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 90/90 [==============================] - 21s 235ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.1587 - val_accuracy: 0.9678
# Epoch 27/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9996WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 90/90 [==============================] - 22s 240ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.1635 - val_accuracy: 0.9594
# Epoch 28/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 90/90 [==============================] - 22s 249ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.1536 - val_accuracy: 0.9678
# Epoch 29/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 90/90 [==============================] - 22s 239ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.1550 - val_accuracy: 0.9678
# Epoch 30/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 90/90 [==============================] - 21s 239ms/step - loss: 0.0048 - accuracy: 0.9993 - val_loss: 0.1619 - val_accuracy: 0.9664

# %%
model.save('model_casia_run1.h5')

# %%
from sklearn.metrics import average_precision_score

predictions = model.predict(X_val)
average_precision = average_precision_score(Y_val, predictions)

# %%
# from sklearn.metrics import precision_recall_curve
# from sklearn.metrics import plot_precision_recall_curve

# disp = plot_precision_recall_curve(model, X_val, Y_val)
# disp.ax_.set_title('2-class Precision-Recall curve: '
#                    'AP={0:0.2f}'.format(average_precision))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-40cedc1a8e3e> in <module>
#       2 from sklearn.metrics import plot_precision_recall_curve
#       3
# ----> 4 disp = plot_precision_recall_curve(model, X_val, Y_val)
#       5 disp.ax_.set_title('2-class Precision-Recall curve: '
#       6                    'AP={0:0.2f}'.format(average_precision))
#
# d:\Documents\A_thesis_documents\Forgery_Detection_Code\fdenv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# d:\Documents\A_thesis_documents\Forgery_Detection_Code\fdenv\lib\site-packages\sklearn\metrics\_plot\precision_recall_curve.py in plot_precision_recall_curve(estimator, X, y, sample_weight, response_method, name, ax, pos_label, **kwargs)
#     204
#     205     y_pred, pos_label = _get_response(
# --> 206         X, estimator, response_method, pos_label=pos_label)
#     207
#     208     precision, recall, _ = precision_recall_curve(y, y_pred,
#
# d:\Documents\A_thesis_documents\Forgery_Detection_Code\fdenv\lib\site-packages\sklearn\metrics\_plot\base.py in _get_response(X, estimator, response_method, pos_label)
#      84
#      85     if not is_classifier(estimator):
# ---> 86         raise ValueError(classification_error)
#      87
#      88     prediction_method = _check_classifier_response_method(
#
# ValueError: Sequential should be a binary classifier

# %%
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="validation loss")
legend = plt.legend(loc='best', shadow=True)
plt.savefig("loss.png", bbox_inches='tight', pad_inches=0)

# %%
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = plt.legend(loc='best', shadow=True)
plt.savefig("acc.png", bbox_inches='tight', pad_inches=0)

# %%
# Plot the loss and accuracy curves for training and validation 
fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
model = tf.keras.models.load_model('model_casia_run1.h5')

# %%
class_names = ['fake', 'real']

# %%
def predict_class(file_paths):
    for file_path in file_paths:
        image = prepare_image(file_path)
        image = image.reshape(-1, 128, 128, 3)
        y_pred = model.predict(image)
        y_pred_class = np.argmax(y_pred, axis = 1)[0]
        print(f'Class: {class_names[y_pred_class]} Confidence: {np.amax(y_pred) * 100:0.2f}')

# %%
fake_image_paths = ['Tp_1407_278731_138.97_198.88_314.05_553.99_person.png','Tp_71_71880_47.87_185.72_531.3_305.38_train.png']
real_image_paths = ['COCO_train2014_000000000025.jpg', '../CASIA2/Au/Au_ani_00001.jpg', '../CASIA2/Au/Au_ani_00001.jpg']

# %%
predict_class(real_image_paths)
# Out:
# Class: fake Confidence: 99.92
# Class: real Confidence: 99.98
# Class: real Confidence: 99.98

# %%
predict_class(fake_image_paths)
# Out:
# Class: fake Confidence: 94.43
# Class: fake Confidence: 98.60

# %%
image = prepare_image('Tp_1407_278731_138.97_198.88_314.05_553.99_person.png')
image = image.reshape(-1, 128, 128, 3)
y_pred = model.predict(image)
y_pred_class = np.argmax(y_pred, axis = 1)[0]
print(f'Class: {y_pred_class} Confidence: {np.amax(y_pred) * 100:0.2f}')
# Out:
# Class: 0 Confidence: 94.43

# %%
y_pred.shape
# Out:
# (1, 2)
